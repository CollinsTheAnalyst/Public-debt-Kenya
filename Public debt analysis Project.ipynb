# %%
import pandas as pd

# %%
import seaborn as sns

# %%
debt = pd.read_csv(r"C:\Users\admin\Downloads\Public Debt.csv")

# %%
debt
# Out:
#      Year      Month  Domestic Debt  External Debt        Total
# 0    1999  September      183417.00      320137.00    503554.00
# 1    1999   December      190300.00      311953.00    502253.00
# 2    2000      March      201463.22      396800.00    598263.22
# 3    2000       June      206127.00      395694.00    601821.00
# 4    2000  September      202362.00      394667.37    597029.37
# ..    ...        ...            ...            ...          ...
# 284  2023  September     4990750.73     5896502.32  10887253.05
# 285  2023   December     5050108.54     6089584.98  11139693.52
# 286  2024      March     5050442.00     6189967.47  11240409.47
# 287  2024       June     5200211.07     5653894.01  10854105.08
# 288  2024  September     5235188.41     5163423.34  10398611.75
#
# [289 rows x 5 columns]

# %%
gdppercapita = pd.read_csv(r"C:\Users\admin\Downloads\gdp-per-capita.csv")

# %%
gdppercapita
# Out:
#     date  GDP Per Capita(US$)  Annual Growth Rate(%)
# 0   1999               430.37                 -11.03
# 1   2000               411.82                  -4.31
# 2   2001               408.36                  -0.84
# 3   2002               401.09                  -1.78
# 4   2003               441.39                  10.05
# 5   2004               462.62                   4.81
# 6   2005               522.78                  13.00
# 7   2006               699.40                  33.79
# 8   2007               840.19                  20.13
# 9   2008               916.00                   9.02
# 10  2009              1049.12                  14.53
# 11  2010              1093.64                   4.24
# 12  2011              1099.32                   0.52
# 13  2012              1289.78                  17.33
# 14  2013              1376.83                   6.75
# 15  2014              1489.92                   8.21
# 16  2015              1496.65                   0.45
# ...

# %%
debtpercapita = pd.read_csv(r"C:\Users\admin\Downloads\debt_per_capita.csv")

# %%
debtpercapita
# Out:
#     date  debt Per Capita (US $)  Annual Growth Rate (%)
# 0   2000                   254.3                     5.1
# 1   2001                   261.2                     2.5
# 2   2002                   273.2                     4.6
# 3   2003                   280.8                     2.9
# 4   2004                   295.4                     5.2
# 5   2005                   322.1                     9.0
# 6   2006                   348.4                     8.2
# 7   2007                   363.7                     4.4
# 8   2008                   385.9                     6.1
# 9   2009                   394.2                     2.1
# 10  2010                   410.1                     4.0
# 11  2011                   423.4                     3.2
# 12  2012                   444.3                     4.9
# 13  2013                   464.2                     4.5
# 14  2014                   478.5                     3.1
# ...

# %%
debtpercapita.dtypes
# Out:
# date                        int64
# debt Per Capita (US $)    float64
# Annual Growth Rate (%)    float64
# dtype: object

# %%
gdppercapita.dtypes
# Out:
# date                       int64
# GDP Per Capita(US$)      float64
# Annual Growth Rate(%)    float64
# dtype: object

# %%
gdp = pd.read_csv(r"C:\Users\admin\Downloads\Annual GDP.csv")

# %%
gdp
# Out:
#     Year  Nominal GDP prices (Ksh Million)  Annual GDP growth (%)  \
# 0   2023                        15108806.0                    5.6
# 1   2022                        13489642.0                    4.9
# 2   2021                        12027662.0                    7.6
# 3   2020                        10715070.0                   -0.3
# 4   2019                        10237727.0                    5.1
# 5   2018                         9340307.0                    5.6
# 6   2017                         8483396.0                    3.8
# 7   2016                         7594064.0                    4.2
# 8   2015                         6884317.0                    5.0
# 9   2014                         6003835.0                    5.0
# 10  2013                         5311322.0                    3.8
# 11  2012                         4767191.0                    4.6
# 12  2011                         4162514.0                    5.1
# ...

# %%
debt
# Out:
#      Year      Month  Domestic Debt  External Debt        Total
# 0    1999  September      183417.00      320137.00    503554.00
# 1    1999   December      190300.00      311953.00    502253.00
# 2    2000      March      201463.22      396800.00    598263.22
# 3    2000       June      206127.00      395694.00    601821.00
# 4    2000  September      202362.00      394667.37    597029.37
# ..    ...        ...            ...            ...          ...
# 284  2023  September     4990750.73     5896502.32  10887253.05
# 285  2023   December     5050108.54     6089584.98  11139693.52
# 286  2024      March     5050442.00     6189967.47  11240409.47
# 287  2024       June     5200211.07     5653894.01  10854105.08
# 288  2024  September     5235188.41     5163423.34  10398611.75
#
# [289 rows x 5 columns]

# %%
debt.head(10)
# Out:
#    Year      Month  Domestic Debt  External Debt      Total
# 0  1999  September      183417.00      320137.00  503554.00
# 1  1999   December      190300.00      311953.00  502253.00
# 2  2000      March      201463.22      396800.00  598263.22
# 3  2000       June      206127.00      395694.00  601821.00
# 4  2000  September      202362.00      394667.37  597029.37
# 5  2000   December      196584.00      395710.06  592294.06
# 6  2000      March      195520.00      399798.72  595318.72
# 7  2000       June      195564.00      400203.03  595767.03
# 8  2000  September      195906.00      400714.45  596620.45
# 9  2000   December      192665.30      405355.31  598020.61

# %%
debt.describe()
# Out:
#               Year  Domestic Debt  External Debt         Total
# count   289.000000   2.890000e+02   2.890000e+02  2.890000e+02
# mean   2011.702422   1.487770e+06   1.561027e+06  3.048797e+06
# std       6.982222   1.424157e+06   1.524677e+06  2.944094e+06
# min    1999.000000   1.834170e+05   3.119530e+05  5.022530e+05
# 25%    2006.000000   3.460640e+05   4.226479e+05  7.572083e+05
# 50%    2012.000000   8.721605e+05   7.639710e+05  1.596937e+06
# 75%    2018.000000   2.371651e+06   2.562179e+06  4.901288e+06
# max    2024.000000   5.235188e+06   6.189967e+06  1.124041e+07

# %%
gdp.describe()
# Out:
#               Year  Nominal GDP prices (Ksh Million)  Annual GDP growth (%)  \
# count    24.000000                      2.400000e+01              24.000000
# mean   2011.500000                      5.558665e+06               4.320833
# std       7.071068                      4.391762e+06               2.214768
# min    2000.000000                      9.678380e+05              -0.300000
# 25%    2005.750000                      1.570880e+06               3.575000
# 50%    2011.500000                      4.464852e+06               4.950000
# 75%    2017.250000                      8.697624e+06               5.600000
# max    2023.000000                      1.510881e+07               8.100000
#
#        Real GDP prices (Ksh Million)
# count                   2.400000e+01
# mean                    5.238001e+06
# std                     3.452537e+06
# min                     9.828550e+05
# 25%                     1.230298e+06
# 50%                     6.229327e+06
# ...

# %%
debt.dtypes
# Out:
# Year               int64
# Month             object
# Domestic Debt    float64
# External Debt    float64
# Total            float64
# dtype: object

# %%
gdp.dtypes
# Out:
# Year                                  int64
# Nominal GDP prices (Ksh Million)    float64
# Annual GDP growth (%)               float64
# Real GDP prices (Ksh Million)       float64
# dtype: object

# %%
print(debt.head())
print(debt.columns)
# Out:
#    Year      Month  Domestic Debt  External Debt      Total
# 0  1999  September      183417.00      320137.00  503554.00
# 1  1999   December      190300.00      311953.00  502253.00
# 2  2000      March      201463.22      396800.00  598263.22
# 3  2000       June      206127.00      395694.00  601821.00
# 4  2000  September      202362.00      394667.37  597029.37
# Index(['Year', 'Month', 'Domestic Debt', 'External Debt', 'Total'], dtype='object')

# %%
# Print columns with their index for better visibility
for i, col in enumerate(debt.columns):
    print(f"Index {i}: '{col}'")
# Out:
# Index 0: 'Year'
# Index 1: 'Month'
# Index 2: 'Domestic Debt'
# Index 3: 'External Debt'
# Index 4: 'Total'

# %%
# Strip whitespace from all column names
debt.columns = debt.columns.str.strip()
debt.columns
# Out:
# Index(['Year', 'Month', 'Domestic Debt', 'External Debt', 'Total'], dtype='object')

# %%
debt.dtypes
# Out:
# Year               int64
# Month             object
# Domestic Debt    float64
# External Debt    float64
# Total            float64
# dtype: object

# %%
# Create a 'Date' column by combining 'Year' and 'Month'
debt['Date'] = pd.to_datetime(debt['Year'].astype(str) + '-' + debt['Month'].astype(str) + '-01')

# %%
debt.dtypes
# Out:
# Year                      int64
# Month                    object
# Domestic Debt           float64
# External Debt           float64
# Total                   float64
# Date             datetime64[ns]
# dtype: object

# %%
debt.head(5)
# Out:
#    Year      Month  Domestic Debt  External Debt      Total       Date
# 0  1999  September      183417.00      320137.00  503554.00 1999-09-01
# 1  1999   December      190300.00      311953.00  502253.00 1999-12-01
# 2  2000      March      201463.22      396800.00  598263.22 2000-03-01
# 3  2000       June      206127.00      395694.00  601821.00 2000-06-01
# 4  2000  September      202362.00      394667.37  597029.37 2000-09-01

# %%
debt.head(5)
# Out:
#    Year      Month  Domestic Debt  External Debt      Total       Date
# 0  1999  September      183417.00      320137.00  503554.00 1999-09-01
# 1  1999   December      190300.00      311953.00  502253.00 1999-12-01
# 2  2000      March      201463.22      396800.00  598263.22 2000-03-01
# 3  2000       June      206127.00      395694.00  601821.00 2000-06-01
# 4  2000  September      202362.00      394667.37  597029.37 2000-09-01

# %%
debt.dtypes
# Out:
# Year                      int64
# Month                    object
# Domestic Debt           float64
# External Debt           float64
# Total                   float64
# Date             datetime64[ns]
# dtype: object

# %%
# Convert 'Date' column to datetime64 format
debt['Date'] = pd.to_datetime(debt['Date'], format='%Y-%m')

# %%
debt.dtypes
# Out:
# Year                      int64
# Month                    object
# Domestic Debt           float64
# External Debt           float64
# Total                   float64
# Date             datetime64[ns]
# dtype: object

# %%
# Convert the 'Date' column to show only year and month
debt['Date'] = debt['Date'].dt.strftime('%Y-%m')

# %% [markdown]
# ## Lets begin the analysis

# %%
debt.dtypes
# Out:
# Year                      int64
# Month                    object
# Domestic Debt           float64
# External Debt           float64
# Total                   float64
# Date             datetime64[ns]
# dtype: object

# %%
debt
# Out:
#      Year      Month  Domestic Debt  External Debt        Total       Date
# 0    1999  September      183417.00      320137.00    503554.00 1999-09-01
# 1    1999   December      190300.00      311953.00    502253.00 1999-12-01
# 2    2000      March      201463.22      396800.00    598263.22 2000-03-01
# 3    2000       June      206127.00      395694.00    601821.00 2000-06-01
# 4    2000  September      202362.00      394667.37    597029.37 2000-09-01
# ..    ...        ...            ...            ...          ...        ...
# 284  2023  September     4990750.73     5896502.32  10887253.05 2023-09-01
# 285  2023   December     5050108.54     6089584.98  11139693.52 2023-12-01
# 286  2024      March     5050442.00     6189967.47  11240409.47 2024-03-01
# 287  2024       June     5200211.07     5653894.01  10854105.08 2024-06-01
# 288  2024  September     5235188.41     5163423.34  10398611.75 2024-09-01
#
# [289 rows x 6 columns]

# %%
# Ensure 'Date' is in datetime format
debt['Date'] = pd.to_datetime(debt['Date'], errors='coerce')

# Convert 'Date' to a Period format showing year and month
debt['Date'] = debt['Date'].dt.to_period('M')

# %%
debt.dtypes
# Out:
# Year                 int64
# Month               object
# Domestic Debt      float64
# External Debt      float64
# Total              float64
# Date             period[M]
# dtype: object

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.interpolate import make_interp_spline

# Ensure 'Date' is in datetime format (if it's not already)
debt['Date'] = pd.to_datetime(debt['Date'])

# Sort the data by 'Date' to ensure it's in ascending order
debt = debt.sort_values('Date').drop_duplicates(subset='Date')

# Set the figure size
plt.figure(figsize=(12, 6))

# Convert 'Date' to numerical values for interpolation
debt['Date_numeric'] = debt['Date'].map(pd.Timestamp.toordinal)

# Create smoother lines using interpolation for Domestic Debt
x_smooth = np.linspace(debt['Date_numeric'].min(), debt['Date_numeric'].max(), 500)
spl_domestic = make_interp_spline(debt['Date_numeric'], debt['Domestic Debt'], k=3)
y_smooth_domestic = spl_domestic(x_smooth)

# Create smoother lines using interpolation for External Debt
spl_external = make_interp_spline(debt['Date_numeric'], debt['External Debt'], k=3)
y_smooth_external = spl_external(x_smooth)

# Convert x_smooth back to datetime using ordinals
x_smooth_dates = [pd.Timestamp.fromordinal(int(date)) for date in x_smooth]

# Plot the smooth lines
plt.plot(x_smooth_dates, y_smooth_domestic, label='Domestic Debt', color='blue')
plt.plot(x_smooth_dates, y_smooth_external, label='External Debt', color='orange')

# Add titles and labels
plt.title('Trends in Domestic and External Debt Over Time', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Debt Amount (in currency)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group by year and calculate total domestic and external debt
debt['Year'] = debt['Date'].dt.year
annual_debt = debt.groupby('Year').agg(
    Total_Domestic_Debt=('Domestic Debt', 'sum'),
    Total_External_Debt=('External Debt', 'sum')
).reset_index()

# Calculate the Debt Ratio for each year
annual_debt['Debt Ratio'] = annual_debt['Total_Domestic_Debt'] / annual_debt['Total_External_Debt']

# Set the figure size
plt.figure(figsize=(12, 6))

# Plot Annual Debt Ratio
plt.plot(annual_debt['Year'], annual_debt['Debt Ratio'], label='Domestic to External Debt Ratio', marker='o', color='purple')

# Set x-axis ticks with a difference of 2 years
plt.xticks(ticks=annual_debt['Year'][::2])  # Show every 2nd year

# Add titles and labels
plt.title('Annual Domestic to External Debt Ratio', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Debt Ratio')
plt.axhline(y=1, color='r', linestyle='--', label='Ratio = 1 (Equal Debt)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# Print the annual ratio values
print(annual_debt[['Year', 'Debt Ratio']])
# Out:
#     Year  Debt Ratio
# 0   1999    0.591240
# 1   2000    0.509540
# 2   2001    0.514980
# 3   2002    0.627960
# 4   2003    0.725623
# 5   2004    0.707882
# 6   2005    0.705941
# 7   2006    0.865580
# 8   2007    0.963199
# 9   2008    0.976514
# 10  2009    0.978631
# 11  2010    1.172081
# 12  2011    1.148020
# 13  2012    1.183595
# 14  2013    1.205668
# 15  2014    1.270073
# 16  2015    1.023113
# 17  2016    0.988920
# 18  2017    0.926116
# 19  2018    0.950016
# 20  2019    0.947173
# 21  2020    0.922822
# 22  2021    0.952603
# 23  2022    0.986037
# 24  2023    0.898604
# 25  2024    0.910542

# %%
# Extract year from the Date column
debt['Year'] = debt['Date'].dt.year

# Group by Year and calculate totals
annual_debt = debt.groupby('Year').agg({
    'Domestic Debt': 'sum',
    'External Debt': 'sum'
}).reset_index()

# Calculate the Debt Ratio
annual_debt['Debt Ratio'] = annual_debt['Domestic Debt'] / annual_debt['External Debt']

# Set the figure size
plt.figure(figsize=(22, 6))

# Plotting Domestic and External Debt
plt.subplot(1, 2, 1)
plt.bar(annual_debt['Year'] - 0.2, annual_debt['Domestic Debt'], width=0.4, label='Domestic Debt', color='blue')
plt.bar(annual_debt['Year'] + 0.2, annual_debt['External Debt'], width=0.4, label='External Debt', color='orange')
plt.title('Total Domestic and External Debt by Year', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Debt Amount')
plt.xticks(annual_debt['Year'])
plt.legend()
plt.grid(axis='y')

# Set x-axis ticks with a difference of 2 years
plt.xticks(ticks=annual_debt['Year'][::2])  # Show every 2nd year

# Show the plots
plt.tight_layout()
plt.show()

# Print the annual debt values
print(annual_debt)
# Out:
#     Year  Domestic Debt  External Debt  Debt Ratio
# 0   1999      373717.00      632090.00    0.591240
# 1   2000      806536.22     1582871.43    0.509540
# 2   2001      820535.13     1593333.05    0.514980
# 3   2002      949115.60     1511427.23    0.627960
# 4   2003     1141135.28     1572628.22    0.725623
# 5   2004     1209637.84     1708812.43    0.707882
# 6   2005     1224112.09     1734014.29    0.705941
# 7   2006     1459202.86     1685809.07    0.865580
# 8   2007     1605930.02     1667287.47    0.963199
# 9   2008     1774425.30     1817100.88    0.976514
# 10  2009     2041159.92     2085730.89    0.978631
# 11  2010     2597730.41     2216340.27    1.172081
# 12  2011     3016222.45     2627325.99    1.148020
# 13  2012     3522583.06     2976172.60    1.183595
# 14  2013     4093179.61     3394946.46    1.205668
# 15  2014     4950440.68     3897761.75    1.270073
# 16  2015     5589114.11     5462851.03    1.023113
# ...

# %% [markdown]
# ## Pie Chart of Debt Composition

# %%
latest_year = annual_debt['Year'].max()
latest_data = annual_debt[annual_debt['Year'] == latest_year]

plt.figure(figsize=(4, 3))
plt.pie(latest_data[['Domestic Debt', 'External Debt']].values.flatten(), 
        labels=['Domestic Debt', 'External Debt'], 
        autopct='%1.1f%%', startangle=90, colors=['blue', 'orange'])
plt.title(f'Debt Composition in {latest_year}', fontweight='bold')
plt.axis('equal')  
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate total debt for Domestic and External across all years
total_debt = annual_debt[['Domestic Debt', 'External Debt']].sum()

plt.figure(figsize=(4, 3))
plt.pie(total_debt.values.flatten(), 
        labels=['Domestic Debt', 'External Debt'], 
        autopct='%1.1f%%', startangle=90, colors=['blue', 'orange'])
plt.title('Total Debt Composition', fontweight='bold')
plt.axis('equal')  
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Calculate total debt
debt['Total Debt'] = debt['Domestic Debt'] + debt['External Debt']

# Aggregate total domestic and external debt
total_domestic_debt = debt['Domestic Debt'].sum()
total_external_debt = debt['External Debt'].sum()
total_debt = total_domestic_debt + total_external_debt

# Create the first pie chart for Domestic vs Total Debt
plt.figure(figsize=(8, 5))

# Pie chart for Domestic Debt
plt.subplot(1, 2, 1)  # 1 row, 2 columns, 1st subplot
plt.pie([total_domestic_debt, total_debt],
        labels=['Domestic Debt', 'Total Debt'],
        autopct='%1.1f%%', startangle=90, colors=['orange', 'blue'])
plt.title('Domestic Debt vs Total Debt', fontweight='bold')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Create the second pie chart for External vs Total Debt
plt.subplot(1, 2, 2)  # 1 row, 2 columns, 2nd subplot
plt.pie([total_external_debt, total_debt],
        labels=['External Debt' ,'Total Debt'],
        autopct='%1.1f%%', startangle=90, colors=['orange', 'lightcoral'])
plt.title('External Debt vs Total Debt', fontweight='bold')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Show the pie charts
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bar Chart of Yearly Growth Rates

# %%
## Calculate the growth rate for domestic and external debt year-over-year and visualize it with a bar chart.

# %%
annual_debt['Domestic Growth Rate'] = annual_debt['Domestic Debt'].pct_change() * 100
annual_debt['External Growth Rate'] = annual_debt['External Debt'].pct_change() * 100

plt.figure(figsize=(15, 6))
plt.bar(annual_debt['Year'] - 0.2, annual_debt['Domestic Growth Rate'], width=0.4, label='Domestic Growth Rate', color='blue')
plt.bar(annual_debt['Year'] + 0.2, annual_debt['External Growth Rate'], width=0.4, label='External Growth Rate', color='orange')
plt.title('Yearly Growth Rates of Domestic and External Debt', fontweight='bold', fontsize=20)
plt.xlabel('Year', fontweight='bold', fontsize=18)
plt.ylabel('Growth Rate (%)', fontweight='bold', fontsize=18)
plt.xticks(annual_debt['Year'])
plt.legend(fontsize=18)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Scatter Plot of Debt Ratio vs. Domestic Debt

# %% [markdown]
# ## Stacked Area Chart

# %%
## Visualize the change in the proportions of domestic and external debt over the years with a stacked area chart.

# %%
plt.figure(figsize=(15, 7))
plt.fill_between(annual_debt['Year'], annual_debt['Domestic Debt'], color='blue', alpha=0.6, label='Domestic Debt')
plt.fill_between(annual_debt['Year'], annual_debt['Domestic Debt'], annual_debt['Domestic Debt'] + annual_debt['External Debt'], color='orange', alpha=0.6, label='External Debt')
plt.title('Stacked Area Chart of Domestic and External Debt Over Time', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Debt Amount (Millions)')
plt.xticks(annual_debt['Year'])
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Ensure the GDP DataFrame is sorted by Year
gdp = gdp.sort_values('Year')

# Calculate the moving average for smoothing
gdp['Nominal GDP MA'] = gdp['Nominal GDP prices (Ksh Million)'].rolling(window=3).mean()
gdp['Real GDP MA'] = gdp['Real GDP prices (Ksh Million)'].rolling(window=3).mean()

# Plot the Yearly Trend for both Nominal and Real GDP
plt.figure(figsize=(10, 6))

# Plot Nominal GDP Trend with smoothing
sns.lineplot(x='Year', y='Nominal GDP MA', data=gdp, label='Nominal GDP', marker='o', color='blue')

# Plot Real GDP Trend with smoothing
sns.lineplot(x='Year', y='Real GDP MA', data=gdp, label='Real GDP', marker='o', color='orange')

# Add titles and labels
plt.title('Yearly GDP Trend (Nominal vs Real)', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('GDP (Ksh Million)')
plt.legend()

# Set x-ticks to show every 2 years
plt.xticks(gdp['Year'][::2], rotation=45)  # Adjust rotation for better readability
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Create a figure
plt.figure(figsize=(12, 5.5))

# Define colors based on the value of 'Annual GDP growth (%)'
def get_color(value):
    if value < 0:
        return 'red'         # Negative values
    elif 0 <= value <= 3.5:
        return 'yellow'      # Values between 0 and 3.5
    else:
        return 'green'     # Values above 3.5

# Apply the color function to create an array of colors
colors = [get_color(value) for value in gdp['Annual GDP growth (%)']]

# Create the bar plot with the specified colors
sns.barplot(x='Year', y='Annual GDP growth (%)', data=gdp, palette=colors)

# Add titles and labels
plt.title('Annual GDP Growth (%) Trend', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('GDP Growth (%)')

# Add data labels on top of the bars
for index, value in enumerate(gdp['Annual GDP growth (%)']):
    plt.text(index, value + 0.2 if value > 0 else value - 0.2, f'{value:.1f}%', 
             ha='center', va='bottom' if value > 0 else 'top', color='black')

plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of tick-labels
plt.show()

# %% [markdown]
# ## GDP per capita vs Debt per capita

# %%
percapita = pd.read_csv(r"C:\Users\admin\Downloads\per-capita.csv")

# %%
percapita
# Out:
#     date  GDP Per Capita(US$)  Annual per capita Growth Rate(%)(gdp)  \
# 0   2000               411.82                                  -4.31
# 1   2001               408.36                                  -0.84
# 2   2002               401.09                                  -1.78
# 3   2003               441.39                                  10.05
# 4   2004               462.62                                   4.81
# 5   2005               522.78                                  13.00
# 6   2006               699.40                                  33.79
# 7   2007               840.19                                  20.13
# 8   2008               916.00                                   9.02
# 9   2009              1049.12                                  14.53
# 10  2010              1093.64                                   4.24
# 11  2011              1099.32                                   0.52
# 12  2012              1289.78                                  17.33
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'percapita' DataFrame is already defined and contains the necessary columns.

# Set the figure size
plt.figure(figsize=(12, 6))

# The width of the bars
bar_width = 0.35

# Set the positions of the bars on the x-axis
index = np.arange(len(percapita['date']))

# Plot the bars for GDP Per Capita
gdp_bars = plt.bar(index - bar_width/2, percapita['GDP Per Capita(US$)'], bar_width, label='GDP Per Capita', color='blue')

# Plot the bars for Debt Per Capita
debt_bars = plt.bar(index + bar_width/2, percapita['debt Per Capita(US$)'], bar_width, label='Debt Per Capita', color='orange')

# Adding the title and labels
plt.title('Comparison of GDP Per Capita vs Debt Per Capita Over Time', fontweight='bold', fontsize=16)
plt.xlabel('Year', fontweight='bold', fontsize=14)
plt.ylabel('Per Capita (US$)', fontweight='bold', fontsize=14)

# Define years to display (every second index)
years_to_display = index[::2]

# Set the x-ticks to be the years (every second year)
plt.xticks(years_to_display, percapita['date'][::2], rotation=45)

# Add legend
plt.legend(fontsize=12)

# Add a grid on the y-axis
plt.grid(axis='y')

# Adjust the layout to make room for the x-axis labels
plt.tight_layout()

# --- Annotate the Highest and Lowest Values ---

# Find the highest and lowest GDP Per Capita
max_gdp_index = percapita['GDP Per Capita(US$)'].idxmax()
min_gdp_index = percapita['GDP Per Capita(US$)'].idxmin()

# Find the highest and lowest Debt Per Capita
max_debt_index = percapita['debt Per Capita(US$)'].idxmax()
min_debt_index = percapita['debt Per Capita(US$)'].idxmin()

# Label the highest and lowest GDP Per Capita
plt.text(max_gdp_index - bar_width/2, percapita['GDP Per Capita(US$)'][max_gdp_index] + 50, 
         f'{percapita["GDP Per Capita(US$)"][max_gdp_index]:,.0f}', ha='center', fontsize=10, color='black', fontweight='bold')

plt.text(min_gdp_index - bar_width/2, percapita['GDP Per Capita(US$)'][min_gdp_index] + 50, 
         f'{percapita["GDP Per Capita(US$)"][min_gdp_index]:,.0f}', ha='center', fontsize=10, color='black', fontweight='bold')

# Label the highest and lowest Debt Per Capita
plt.text(max_debt_index + bar_width/2, percapita['debt Per Capita(US$)'][max_debt_index] + 50, 
         f'{percapita["debt Per Capita(US$)"][max_debt_index]:,.0f}', ha='center', fontsize=10, color='black', fontweight='bold')

plt.text(min_debt_index + bar_width/2, percapita['debt Per Capita(US$)'][min_debt_index] + 50, 
         f'{percapita["debt Per Capita(US$)"][min_debt_index]:,.0f}', ha='center', fontsize=10, color='black', fontweight='bold')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate the total GDP Per Capita and total Debt Per Capita
total_gdp_per_capita = percapita['GDP Per Capita(US$)'].sum()
total_debt_per_capita = percapita['debt Per Capita(US$)'].sum()

# Create the labels and sizes for the pie chart
labels = ['Total GDP Per Capita', 'Total Debt Per Capita']
sizes = [total_gdp_per_capita, total_debt_per_capita]
colors = ['#4CAF50', '#FF6F61']

# Create the pie chart
plt.figure(figsize=(6, 6))
wedges, texts, autotexts = plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90, wedgeprops={'edgecolor': 'black'})

# Customize the label text appearance
for text in texts:
    text.set_fontweight('bold')  # Set the font weight of the labels to bold
for autotext in autotexts:
    autotext.set_fontweight('bold')  # Set the font weight of the percentage labels to bold

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

# Add a title
plt.title('Total GDP Per Capita vs Debt Per Capita', fontweight='bold', fontsize=16)

# Display the pie chart
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter the debt dataset for records where the Month is 'June'
debt_june = debt[debt['Month'] == 'June']

# Group by year and get the last entry for each year (in June)
debt_june_grouped = debt_june.groupby('Year').last().reset_index()

# Merge GDP and Debt (only for June) dataframes on 'Year'
merged_data = pd.merge(
    debt_june_grouped[['Year', 'Domestic Debt', 'External Debt', 'Total']],
    gdp[['Year', 'Nominal GDP prices (Ksh Million)']],
    on='Year', how='inner'
)

# Rename the GDP column for easier access
merged_data.rename(columns={'Nominal GDP prices (Ksh Million)': 'Nominal GDP (Million Ksh)'}, inplace=True)

# Calculate the Debt-to-GDP ratio
merged_data['Debt-to-GDP Ratio (%)'] = (merged_data['Total'] / merged_data['Nominal GDP (Million Ksh)']) * 100

# Convert Nominal GDP and Total Debt from Ksh Million to Billion for better readability
merged_data['Nominal GDP (Billion Ksh)'] = merged_data['Nominal GDP (Million Ksh)'] / 1e3
merged_data['Total Debt (Billion Ksh)'] = merged_data['Total'] / 1e3

# Set the figure size
fig, ax1 = plt.subplots(figsize=(16, 6))

# Bar width for side-by-side charts
bar_width = 0.4
years = merged_data['Year']
years_index = range(len(years))

# Side-by-side bar charts for Nominal GDP and Total Public Debt (as of June)
bars_gdp = ax1.bar([x - bar_width/2 for x in years_index], 
                    merged_data['Nominal GDP (Billion Ksh)'], 
                    width=bar_width, 
                    label='Nominal GDP (Billion Ksh)', 
                    color='blue')

bars_debt = ax1.bar([x + bar_width/2 for x in years_index], 
                     merged_data['Total Debt (Billion Ksh)'], 
                     width=bar_width, 
                     label='Total Public Debt (as of June, Billion Ksh)', 
                     color='orange')

# Labels for the bar chart
ax1.set_xlabel('Year', fontsize=14, fontweight='bold')
ax1.set_ylabel('Amount (in Billion Ksh)', fontsize=14, fontweight='bold')
ax1.set_xticks(years_index)
ax1.set_xticklabels(years)
ax1.legend(loc='upper left')

# Create a twin y-axis for the Debt-to-GDP ratio (line plot)
ax2 = ax1.twinx()
line_plot = ax2.plot(years_index, 
                     merged_data['Debt-to-GDP Ratio (%)'], 
                     color='green', 
                     label='Debt-to-GDP Ratio (%)', 
                     linewidth=2, 
                     marker='o')

# Labels for the line chart
ax2.set_ylabel('Debt-to-GDP Ratio (%)', fontsize=14, fontweight='bold')
ax2.legend(loc='upper right')

# Annotate specific years (2002, 2009, 2022) on the line trend
specific_years = [2002, 2009, 2022]
for i, year in enumerate(merged_data['Year']):
    if year in specific_years:
        ax2.annotate(f'{merged_data["Debt-to-GDP Ratio (%)"].iloc[i]:.1f}%', 
                     xy=(i, merged_data['Debt-to-GDP Ratio (%)'].iloc[i]), 
                     xytext=(0, 10),  # Offset text vertically
                     textcoords='offset points', 
                     ha='center', 
                     fontsize=14,
                     fontweight='bold',
                     color='black')


# Title
plt.title('Nominal GDP, Total Public Debt, and Debt-to-GDP Ratio', fontsize=18, fontweight='bold')

# Show the plots
plt.tight_layout()
plt.show()

# Print the merged data for verification
print(merged_data)
# Out:
#     Year  Domestic Debt  External Debt        Total  \
# 0   2000      195564.00      400203.03    595767.03
# 1   2001      225952.00      389276.05    615228.05
# 2   2002      251196.67      373140.09    624336.76
# 3   2003      301918.96      409359.85    711278.82
# 4   2004      301541.30      454539.95    756081.25
# 5   2005      332725.65      418417.49    751143.14
# 6   2006      375524.02      424414.09    799938.11
# 7   2007      418488.14      419738.84    838226.99
# 8   2008      454685.97      434487.59    889173.56
# 9   2009      567125.13      523899.66   1091024.79
# 10  2010      696132.65      598080.46   1294213.11
# 11  2011      794565.56      810011.60   1604577.16
# 12  2012      929321.62      812307.84   1741629.46
# 13  2013     1174782.27      887991.23   2062773.50
# 14  2014     1254913.42     1088832.15   2343745.57
# 15  2015     1454245.39     1490713.76   2944959.15
# 16  2016     1872102.82     1844474.95   3716577.78
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter the debt dataset for records where the Month is 'June'
debt_june = debt[debt['Month'] == 'June']

# Group by year and get the last entry for each year (in June)
debt_june_grouped = debt_june.groupby('Year').last().reset_index()

# Merge GDP and Debt (only for June) dataframes on 'Year'
merged_data = pd.merge(
    debt_june_grouped[['Year', 'Domestic Debt', 'External Debt', 'Total']],
    gdp[['Year', 'Nominal GDP prices (Ksh Million)']],
    on='Year', how='inner'
)

# Rename the GDP column for easier access
merged_data.rename(columns={'Nominal GDP prices (Ksh Million)': 'Nominal GDP (Million Ksh)'}, inplace=True)

# Calculate the Debt-to-GDP ratio
merged_data['Debt-to-GDP Ratio (%)'] = (merged_data['Total'] / merged_data['Nominal GDP (Million Ksh)']) * 100

# Calculate the growth rates
merged_data['GDP Growth (%)'] = merged_data['Nominal GDP (Million Ksh)'].pct_change() * 100
merged_data['Total Debt Growth (%)'] = merged_data['Total'].pct_change() * 100

# Set the figure size
plt.figure(figsize=(16, 6))

# Plotting GDP Growth
plt.plot(merged_data['Year'], merged_data['GDP Growth (%)'], color='green', marker='o', label='GDP Growth (%)')

# Plotting Total Debt Growth
plt.plot(merged_data['Year'], merged_data['Total Debt Growth (%)'], color='red', marker='x', label='Total Debt Growth (%)')

# Add labels for specific years
for i, txt in enumerate(merged_data['GDP Growth (%)']):
    if merged_data['Year'][i] in [2002, 2013, 2023]:  # Years of interest
        plt.annotate(f"{txt:.1f}%", 
                     (merged_data['Year'][i], merged_data['GDP Growth (%)'][i]), 
                     textcoords="offset points", 
                     xytext=(0,10), 
                     ha='center', 
                     fontsize=10, 
                     color='blue')

# Labels and title
plt.title('GDP Growth vs Total Debt Growth', fontsize=18, fontweight='bold')
plt.xlabel('Year', fontsize=14, fontweight='bold')
plt.ylabel('Growth Rate (%)', fontsize=14, fontweight='bold')
plt.xticks(merged_data['Year'], rotation=45)
plt.legend()
plt.grid()

# Show the plots
plt.tight_layout()
plt.show()

# Print the merged data for verification
print(merged_data[['Year', 'GDP Growth (%)', 'Total Debt Growth (%)']])
# Out:
#     Year  GDP Growth (%)  Total Debt Growth (%)
# 0   2000             NaN                    NaN
# 1   2001        5.391811               3.266549
# 2   2002        1.505066               1.480542
# 3   2003        9.311514              13.925507
# 4   2004       12.594729               6.298856
# 5   2005       11.103499              -0.653119
# 6   2006       14.602249               6.496095
# 7   2007       13.000773               4.786480
# 8   2008       14.948260               6.077897
# 9   2009       55.421289              22.700993
# 10  2010        9.829768              18.623621
# 11  2011       15.701559              23.980908
# 12  2012       14.526726               8.541334
# 13  2013       11.414080              18.439286
# 14  2014       13.038430              13.621082
# 15  2015       14.665326              25.651828
# 16  2016       10.309621              26.201336
# 17  2017       11.710884              22.199363
# 18  2018       10.101037              14.285759
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter the debt dataset for records where the Month is 'June'
debt_june = debt[debt['Month'] == 'June']

# Group by year and get the last entry for each year (in June)
debt_june_grouped = debt_june.groupby('Year').last().reset_index()

# Merge GDP and Debt (only for June) dataframes on 'Year'
merged_data = pd.merge(
    debt_june_grouped[['Year', 'Domestic Debt', 'External Debt', 'Total']],
    gdp[['Year', 'Nominal GDP prices (Ksh Million)']],
    on='Year', how='inner'
)

# Rename the GDP column for easier access
merged_data.rename(columns={'Nominal GDP prices (Ksh Million)': 'Nominal GDP (Million Ksh)'}, inplace=True)

# Calculate the Debt-to-GDP ratio
merged_data['Debt-to-GDP Ratio (%)'] = (merged_data['Total'] / merged_data['Nominal GDP (Million Ksh)']) * 100

# Set the figure size
fig, ax1 = plt.subplots(figsize=(16, 6))

# Plot the stacked bar chart for Domestic and External Debt
ax1.bar(merged_data['Year'], merged_data['Domestic Debt'] / 1e3, label='Domestic Debt (Billion Ksh)', color='blue')
ax1.bar(merged_data['Year'], merged_data['External Debt'] / 1e3, label='External Debt (Billion Ksh)', 
         bottom=merged_data['Domestic Debt'] / 1e3, color='orange')

# Labels for the bar chart
ax1.set_xlabel('Year', fontsize=14, fontweight='bold')
ax1.set_ylabel('Debt Amount (in Billion Ksh)', fontsize=14, fontweight='bold')
ax1.set_title('Stacked Bar Chart of Domestic and External Debt', fontsize=18, fontweight='bold')

# Create a twin y-axis for the Debt-to-GDP ratio (line plot)
ax2 = ax1.twinx()
ax2.plot(merged_data['Year'], merged_data['Debt-to-GDP Ratio (%)'], 
         color='green', label='Debt-to-GDP Ratio (%)', linewidth=2, marker='o')

# Labels for the line chart
ax2.set_ylabel('Debt-to-GDP Ratio (%)', fontsize=14, fontweight='bold')

# Show legend for both plots
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Set grid for better readability
ax1.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plots
plt.tight_layout()
plt.show()

# Print the merged data for verification
print(merged_data)
# Out:
#     Year  Domestic Debt  External Debt        Total  \
# 0   2000      195564.00      400203.03    595767.03
# 1   2001      225952.00      389276.05    615228.05
# 2   2002      251196.67      373140.09    624336.76
# 3   2003      301918.96      409359.85    711278.82
# 4   2004      301541.30      454539.95    756081.25
# 5   2005      332725.65      418417.49    751143.14
# 6   2006      375524.02      424414.09    799938.11
# 7   2007      418488.14      419738.84    838226.99
# 8   2008      454685.97      434487.59    889173.56
# 9   2009      567125.13      523899.66   1091024.79
# 10  2010      696132.65      598080.46   1294213.11
# 11  2011      794565.56      810011.60   1604577.16
# 12  2012      929321.62      812307.84   1741629.46
# 13  2013     1174782.27      887991.23   2062773.50
# 14  2014     1254913.42     1088832.15   2343745.57
# 15  2015     1454245.39     1490713.76   2944959.15
# 16  2016     1872102.82     1844474.95   3716577.78
# ...

# %%
plt.figure(figsize=(12, 6))

# Plotting GDP Per Capita
plt.plot(percapita['Year'], percapita['GDP Per Capita(US$)'], marker='o', label='GDP Per Capita', color='blue')

# Plotting Debt Per Capita
plt.plot(percapita['Year'], percapita['debt Per Capita(US$)'], marker='o', label='Debt Per Capita', color='orange')

# Adding titles and labels
plt.title('GDP Per Capita vs Debt Per Capita Over Time', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Per Capita (US$)', fontsize=14)

# Setting x-axis ticks to show every 2 years
plt.xticks(ticks=range(percapita['Year'].min(), percapita['Year'].max() + 1, 2), rotation=45)

plt.legend()
plt.grid(True)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from CSV files
debt = pd.read_csv(r"C:\Users\admin\Downloads\Public Debt.csv")
percapita = pd.read_csv(r"C:\Users\admin\Downloads\per-capita.csv")

# Make sure the 'Year' column in the debt DataFrame is in the correct format
debt['Year'] = pd.to_datetime(debt['Year'].astype(str) + ' ' + debt['Month']).dt.year

# Display the unique values in the 'Year' columns for both DataFrames
print("\nUnique Years in Debt DataFrame:", debt['Year'].unique())
print("Unique Years in Per Capita DataFrame:", percapita['date'].unique())

# Rename 'date' to 'Year' in percapita for consistency
percapita.rename(columns={'date': 'Year'}, inplace=True)

# Convert 'Year' in percapita to integer
percapita['Year'] = percapita['Year'].astype(int)

# Filter out the rows for June in the debt DataFrame and calculate % growth in total debt
debt_june = debt[debt['Month'] == 'June'].copy()
debt_june['% Growth in Total Debt'] = debt_june['Total'].pct_change() * 100

# Merge the two DataFrames on 'Year'
merged_df = pd.merge(percapita, debt_june[['Year', '% Growth in Total Debt']], on='Year', how='left')

# Plotting
plt.figure(figsize=(12, 6))

# Plotting % Growth in GDP Per Capita
plt.plot(merged_df['Year'], merged_df['Annual per capita Growth Rate(%)(gdp)'], marker='o', label='GDP Per Capita Growth Rate (%)', color='green')

# Plotting % Growth in Debt Per Capita
plt.plot(merged_df['Year'], merged_df['Annual per capita Growth Rate(%)(debt)'], marker='o', label='Debt Per Capita Growth Rate (%)', color='orange')

# Creating a secondary y-axis for % Growth in Total Debt as a bar chart
ax2 = plt.gca().twinx()  # Twin Axes sharing the x-axis
ax2.bar(merged_df['Year'], merged_df['% Growth in Total Debt'], color='blue', alpha=1, label='% Growth in Total Debt', width=0.4)

# Adding titles and labels
plt.title('Growth Rates: GDP Per Capita, Debt Per Capita, and Total Debt (%)', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Growth Rate (%)', fontsize=14)

# Setting label for the second y-axis
ax2.set_ylabel('% Growth in Total Debt', fontsize=14, color='red')

# Adding legends
plt.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()  # To adjust the layout for better visibility
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5004\3712957527.py:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   debt['Year'] = pd.to_datetime(debt['Year'].astype(str) + ' ' + debt['Month']).dt.year
# Unique Years in Debt DataFrame: [1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012
#  2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024]
# Unique Years in Per Capita DataFrame: [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015 2016 2017 2018 2019 2020 2021 2022]
